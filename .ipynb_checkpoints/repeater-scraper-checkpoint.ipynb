# %%
# immport dependencies
from bs4 import BeautifulSoup
import pandas as pd
import requests
import pymongo
from pymongo import MongoClient

# %%
# MongoDB connection
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# creates repeater db if it doesn't already exist
# drops stations table to avoid duplicate entries
db = client.repeater_db
db.stations.drop()

# %%
# url to scrape & soup setup
url = 'https://www.repeaterbook.com/repeaters/Display_SS.php?state_id=06&band=4&loc=%&call=%&use=%'

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# scrapes url & pushes data to stations table in db
table_rows = soup.find_all('tr')[4:]
for item in table_rows:
    freq = item.find('a').text
    call_sign = item.find_all('td', attrs={'class': None})[3].text
    county = item.find_all('td', attrs={'class': None})[2].text
    location = item.find(class_="w3-left-align").text
    usage = item.find('font').text
    db.stations.insert_one(
        {'location': location,
         'frequency': freq,
         'call sign': call_sign,
         'county': county,
         'usage': usage})
                    
    print(location, freq, call_sign, county, usage)
# Out:
# Moreno Valley 425.4250 KC7NP Riverside  OPEN
# San Jose 430.3000 W6IOS Santa Clara  OPEN
# Chico 440.0000 KI6PNB Butte  OPEN
# Fremont 440.0000 WA6FSP Alameda  OPEN
# Fresno 440.0025 N6VRC Fresno  OPEN
# Sonoma 440.0125 W6PE Sonoma  OPEN
# Fremont 440.0250 KI6KGN Alameda  OPEN
# Pacifica 440.0250 N6TZE San Mateo  OPEN
# Ukiah 440.0250 WA6RQZ Mendocino  OPEN
# Vacaville 440.0250 WV6F Solano  OPEN
# Morgan Hill, Loma Prieta 440.0375 W6YYY Santa Clara  OPEN
# Hayward 440.0500 KQ6YG Alameda  OPEN
# Napa, Mt St Helena 440.0500 W6CO Sonoma  OPEN
# Redding 440.0500 NA0SA Shasta  CLOSED
# Clovis 440.0625 WX6D Fresno  OPEN
# Fresno 440.0625 KE6YJC Fresno  OPEN
# Angwin 440.0750 K6LO Napa  OPEN
# Belmont 440.0750 KR6WP San Mateo  OPEN
# Stockton 440.0750 KE6DXF San Joaquin  OPEN
# Willits 440.0750 WA6RQX Mendocino  CLOSED
# Grass Valley 440.1000 KO6CW Nevada  OPEN
# La Honda 440.1000 WA6DQP San Mateo  OPEN
# Loyalton 440.1000 N5TEN Sierra  CLOSED
# McKinleyville 440.1000 KJ6BDK Humboldt  OPEN
# Saint Helena, Deer Park 440.1000 K6LO Napa  OPEN
# San Jose 440.1000 W6SMQ Santa Clara  OPEN
# West Point, West Point Fire Protection District Station 1 440.1000 W6WPT Calaveras  OPEN
# Cameron Park 440.1250 N6RDE El Dorado  CLOSED
# Cazadero 440.1250 K6CHG Sonoma  OPEN
# Cupertino 440.1250 W6AMT Santa Clara  OPEN
# Fremont, Mt Allison 440.1250 W6TCP Alameda  OPEN
# Fresno, Meadow Lakes 440.1250 KF6FGL Fresno  OPEN
# Santa Maria 440.1250 WA6VPL Santa Barbara  OPEN
# Hopland, Sanel Mountain 440.1375 NN6J Mendocino  OPEN
# Pittsburg 440.1375 K6PIT Contra Costa  OPEN
# Cupertino 440.1500 W6TDM Santa Clara  OPEN
# Zamora 440.1500 W6OF Yolo  CLOSED
# Berkeley 440.1750 K6GOD Alameda  CLOSED
# Fremont, Mission Peak 440.1750 K6GOD Alameda  CLOSED
# Redding 440.1750 NA0SA Shasta  CLOSED
# Modesto, Mt Oso 440.1875 W6BXN Stanislaus  OPEN
# San Luis Obispo, Tassajera Peak 440.1875 K6ACR San Luis Obispo  OPEN
# Palo Alto 440.2000 N6BDE Santa Clara  OPEN
# Sacramento 440.2000 KU6P Sacramento  OPEN
# Santa Rosa 440.2000 KD6CJQ Sonoma  OPEN
# Walnut Creek 440.2125 K6LNK Contra Costa  OPEN
# Modesto, Mt Oso 440.2250 WD6EJF Stanislaus  OPEN
# San Jose 440.2250 K6LLC Santa Clara  OPEN
# Shingletown 440.2250 WO6P Shasta  OPEN
# Novato 440.2500 N6GVI Marin  CLOSED
# Porterville 440.2500 AB6MJ Tulare  CLOSED
# Mt Shasta City, Gray Butte 440.2750 N6QGZ Siskiyou  OPEN
# San Jose 440.2750 WA6YOP Santa Clara  OPEN
# Tahoe City 440.2750 K1BMW Placer  OPEN
# Concord, Mt Diablo 440.3000 N6AMG Contra Costa  CLOSED
# Grant Cove, Buck Rock 440.3000 W6BXN Fresno  OPEN
# Bodega Bay 440.3250 K6CHG Sonoma  OPEN
# Concord 440.3250 WB6FRM Contra Costa  CLOSED
# Lakehead 440.3250 N0ASA Shasta  OPEN
# Clovis 440.3500 NI6M Fresno  OPEN
# Folsom 440.3500 AB6LI Sacramento  OPEN
# Oakland 440.3500 KM6EF Alameda  OPEN
# Fresno 440.3750 N6AMG Fresno  CLOSED
# San Jose 440.3750 N6TNR Santa Clara  CLOSED
# Berkeley 440.4000 WB6WTM Alameda  CLOSED
# Visalia, Park Ridge 440.4000 WA6BAI Fresno  OPEN
# Marysville 440.4250 KG6PND Yuba  OPEN
# San Ramon 440.4250 WA6HAM Contra Costa  CLOSED
# Santa Rosa 440.4500 K6EAR Sonoma  OPEN
# Visalia 440.4500 N6BYH Tulare  OPEN
# Volcano 440.4500 W6KAP Amador  OPEN
# Watsonville 440.4500 W6DXW Santa Cruz  OPEN
# Woodside 440.4500 N6ZX San Mateo  OPEN
# Morgan Hill, Crystal Peak 440.4750 K6GOD Santa Cruz  CLOSED
# Sebastopol 440.4750 WA6FUL Sonoma  OPEN
# Woodland 440.4750 KC6UDS Yolo  OPEN
# Chico 440.5000 WA6UHF Butte  CLOSED
# Daly City, San Bruno Mountain 440.5000 N6AMG San Mateo  OPEN
# San Bruno 440.5000 N6AMG San Mateo  OPEN
# Westley 440.5000 N6AMG Stanislaus  CLOSED
# Coalinga 440.5250 N6LEX Fresno  OPEN
# Grass Valley 440.5250 KB6LCS Nevada  OPEN
# Newark, City by the bay 440.5250 N6MM Alameda  OPEN
# Soledad 440.5250 N6LEX Monterey  OPEN
# Vacaville 440.5250 KB6LCS Solano  OPEN
# Chico 440.5500 WB6RHC Butte  CLOSED
# San Anselmo 440.5500 W6RV Marin  OPEN
# Santa Cruz 440.5500 AB6VS Santa Cruz  OPEN
# Twain Harte 440.5500 KE6KUA Tuolumne  OPEN
# Auburn 440.5750 W6EK Placer  OPEN
# Morgan Hill 440.5750 KA6ZRJ Santa Clara  OPEN
# Oakland 440.5750 W6EBW Alameda  OPEN
# Livermore, Cedar Ridge 440.6000 KI6FEO Alameda  OPEN
# South San Francisco 440.6000 K6HN San Francisco  CLOSED
# Orinda 440.6250 WA6HAM Contra Costa  CLOSED
# Tehachapi, Tehachapi Mountains 440.6250 W6SLZ Kern  OPEN
# Antioch 440.6500 KC6WYA Contra Costa  OPEN
# Chico 440.6500 W6RHC Butte  OPEN
# Danville 440.6500 N6TRB Contra Costa  OPEN
# Los Gatos 440.6500 KC6TYG Santa Clara  OPEN
# Novato 440.6500 KG6MZV Marin  OPEN
# Chico 440.6750 N6EJX Butte  CLOSED
# Coalinga, Santa Rita Peak 440.6750 W6EMS Fresno  OPEN
# Daly City 440.6750 K6TEA San Mateo  CLOSED
# Brisbane 440.7000 K6CV San Mateo  OPEN
# Placerville 440.7000 WA6BTH El Dorado  OPEN
# Salinas 440.7000 W6RTF Monterey  OPEN
# Truckee, Donner Peak 440.7000 W6SAR Placer  OPEN
# Fair Oaks 440.7250 WB6HEV Sacramento  OPEN
# Pacifica 440.7250 WA6AFT San Mateo  CLOSED
# Coalinga 440.7500 K6JKL Fresno  OPEN
# Vacaville, Mt Vaca 440.7500 K6LNK Napa  OPEN
# Concord 440.7750 N6BLA Contra Costa  CLOSED
# Mariposa, Mt Bullion 440.8000 N6LYE Mariposa  OPEN
# Modesto, Mt Oso 440.8000 N6LYE Stanislaus  OPEN
# Mountain View, El Camino Hospital  440.8000 W6ASH Santa Clara  OPEN
# Berkeley 440.8250 WB6IXH Alameda  CLOSED
# Porterville, Jordan Peak 440.8250 W6KGB Tulare  PRIVATE
# Mariposa, Mt Bullion 440.8375 N6LYE Mariposa  OPEN
# Bakersfield 440.8500 KE6CUW Kern  OPEN
# Columbia 440.8500 K6DEL Tuolumne  OPEN
# Napa 440.8500 N6NAR Napa  OPEN
# Santa Cruz 440.8500 W6JWS Santa Cruz  OPEN
# Concord 440.8750 WA6HAM Contra Costa  CLOSED
# Los Altos 440.8750 KH6N Santa Clara  OPEN
# Berkeley 440.9000 WA2UNP Alameda  OPEN
# Mountain Ranch 440.9000 N6GVI Calaveras  CLOSED
# Newark 440.9000 KI6KGN Alameda  OPEN
# Oroville 440.9000 W6SCR Butte  OPEN
# Berkeley 440.9250 KH8AF Alameda  CLOSED
# Novato 440.9250 KH8AF Marin  CLOSED
# San Rafael 440.9250 KH8AF Marin  CLOSED
# Santa Cruz 440.9250 K6BJ Santa Cruz  OPEN
# Tahoe City 440.9250 KH8AF Placer  CLOSED
# Vacaville 440.9250 KH8AF Solano  CLOSED
# Gold Run 440.9500 WB6OHV Placer  OPEN
# Hayward 440.9500 KB6LED Alameda  OPEN
# Redding 440.9500 KB6HWZ Shasta  OPEN
# Sebastopol 440.9500 WA6FUL Sonoma  OPEN
# Columbia 440.9750 N6EUO Tuolumne  OPEN
# Mineral 440.9750 N6TZG Tehama  OPEN
# Portola Valley 440.9750 KC6ULT San Mateo  OPEN
# Richmond 440.9750 K6LOU Contra Costa  CLOSED
# Cameron Park 441.0000 WA6NHC El Dorado  OPEN
# Campbell 441.0250 K9GVF Santa Clara  OPEN
# Grass Valley 441.0250 W6RCA Nevada  OPEN
# Westwood 441.0250 N6TZG Lassen  OPEN
# Los Gatos 441.0500 N6UUI Santa Clara  OPEN
# Paso Robles 441.0500 WB6JWB San Luis Obispo  PRIVATE
# Placerville 441.0500 N6UUI El Dorado  OPEN
# Pacifica, Montara Mountain 441.0750 WA6TOW San Mateo  OPEN
# San Luis Obispo 441.0750 WB6JWB San Luis Obispo  PRIVATE
# Valley Springs 441.0750 W6EBW Calaveras  OPEN
# Clearlake 441.1000 KA6JJW Lake  OPEN
# El Dorado Hills 441.1000 N6QDY El Dorado  OPEN
# Palo Alto, Black Mountain 441.1000 K6GOD Santa Clara  CLOSED
# San Jose, Alum Rock Park 441.1000 K6GOD Santa Clara  CLOSED
# Sebastopol 441.1000 WA6FUL Sonoma  OPEN
# Angels Camp 441.1250 NC6R Calaveras  OPEN
# Esparto 441.1250 NC6R Yolo  OPEN
# Fremont 441.1250 KC6WXO Alameda  OPEN
# Prunedale 441.1250 KC6UDC Monterey  OPEN
# Taft 441.1250  Kern
# Fairfield 441.1500 K6SOL Solano  OPEN
# San Jose 441.1500 KC6BJO Santa Clara  OPEN
# Citrus Heights 441.1750 KG6ZTE Sacramento  OPEN
# Oakhurst, Deadwood Peak 441.1750 W6WGZ Madera  OPEN
# San Jose 441.1750 KF6FWO Santa Clara  OPEN
# Tahoe City 441.1750 N7VXB Placer  OPEN
# Concord 441.2000 N6GVI Contra Costa  CLOSED
# Alturas, Likely Mountain 441.2250 K6PRN Modoc  OPEN
# Camino 441.2250 N6YBH El Dorado  OPEN
# Oakland 441.2250 W6RCA Alameda  OPEN
# Benicia 441.2500 KR6BEN Solano  OPEN
# Los Altos 441.2500 WB6WTM Santa Clara  CLOSED
# Placerville 441.2500 W6LOA El Dorado  OPEN
# South San Francisco 441.2500 K6DNA San Francisco  OPEN
# Modesto, Mt Oso 441.2750 K6RDJ Stanislaus  OPEN
# Mount Shasta 441.2750 W6BML Siskiyou  OPEN
# San Jose 441.2750 K6BEN Santa Clara  CLOSED
# Fremont, Mt Allison 441.3000 WB6ECE Alameda  OPEN
# Monterey 441.3000 WB6ECE Monterey  OPEN
# San Jose, Mt Umunhum 441.3000 WB6ECE Santa Clara  OPEN
# Santa Rosa 441.3000 KV6A Sonoma  OPEN
# Santa Rosa 441.3000 KD6RC Sonoma  OPEN
# Shingle Springs 441.3000 N6NA El Dorado  CLOSED
# Woodside 441.3000 WB6ECE San Mateo  OPEN
# Concord, Mt Diablo 441.3250 W6CX Contra Costa  OPEN
# Monterey 441.3250 WE6R Monterey  CLOSED
# Kelseyville 441.3500 KG6UFR Lake  OPEN
# Mariposa, Mt Bullion 441.3500 K6SIX Mariposa  OPEN
# San Jose 441.3500 W6PIY Santa Clara  OPEN
# Chester 441.3750 N6TZG Plumas  CLOSED
# Sebastopol, English Hill 441.3750 W6SON Sonoma  OPEN
# West Point 441.3750 WB6LZV Calaveras  OPEN
# Chico 441.4000 WB6RHC Butte  OPEN
# Meadow Lakes 441.4000 K6TVI Fresno  CLOSED
# Redwood City 441.4000 WD6GGW San Mateo  OPEN
# Kelseyville 441.4250 N6GJM Lake  OPEN
# Mariposa 441.4250 KF6CLR Mariposa  OPEN
# Oakland 441.4250 W6MTF Alameda  OPEN
# Sacramento 441.4500 KJ6KO Sacramento  OPEN
# Salinas, Fremont Pk 441.4500 K6JE Monterey  OPEN
# San Francisco 441.4500 W6EE San Francisco  OPEN
# San Lorenzo 441.4500 KM6HJA Alameda  OPEN
# Oakland 441.4750 W6YOP Alameda  OPEN
# Oroville 441.4750 W6YOP Butte  OPEN
# Sonora 441.4750 WB6PHE Tuolumne  OPEN
# Los Altos Hills  441.5250 K6AIR Santa Clara  OPEN
# Pine Grove, Mount Zion 441.5250 K6ARC Amador  OPEN
# Porterville 441.5250 WC6HP Tulare  OPEN
# Alpine 441.5500 N6LZR Mendocino  CLOSED
# Cupertino 441.5500 W6VB Santa Clara  CLOSED
# Mariposa, Mt Bullion 441.5500 K6RDJ Mariposa  OPEN
# Georgetown 441.5750 K6IRC El Dorado  CLOSED
# Palo Alto 441.5750 K6IRC Santa Clara  CLOSED
# Merced 441.6000 N6WEB Merced  OPEN
# Vacaville 441.6000 W6RCA Solano  CLOSED
# Livermore 441.6125 W6TCP Alameda  OPEN
# San Carlos 441.6125 W6CBS San Mateo  OPEN
# Los Gatos 441.6250 W6RCA Santa Clara  OPEN
# Placerville 441.6250 W6RCA El Dorado  CLOSED
# Quincy 441.6250 W6RCA Plumas  OPEN
# Copperopolis 441.6500 KD6FVA San Joaquin  OPEN
# King City, Williams Hill 441.6500 N6SPD Monterey  OPEN
# Menlo Park 441.6500 W6FBK San Mateo  OPEN
# Monterey 441.6500 N6SPD Monterey  OPEN
# Santa Rosa, Richmond Heights 441.6500 K6JSI Santa Clara  OPEN
# Coalinga, Santa Rita Peak 441.6750 K6JSI San Benito  CLOSED
# Napa, Sugarloaf 441.6750 WA7G Napa  OPEN
# Santa Cruz 441.6750 N7WG Santa Cruz  OPEN
# Los Gatos 441.7000 K6UB Santa Clara  OPEN
# San Andreas 441.7000 W6ALL Calaveras  CLOSED
# Arnold 441.7250 KD6GIY Calaveras  OPEN
# Lotus, Bakers Mountain 441.7250 AG6AU El Dorado  OPEN
# Pacifica 441.7250 K6HN San Mateo  CLOSED
# San Jose 441.7250 WA6QDP Santa Clara  CLOSED
# Concord 441.7500 W6YOP Contra Costa  OPEN
# Cottonwood 441.7500 AK6U Tehama  OPEN
# Truckee 441.7500 K1BMW Nevada  OPEN
# Giroy, Mt. Madonna 441.7750  Santa Cruz  CLOSED
# Sacramento 441.7750 N6ICW Sacramento  CLOSED
# Vacaville, Mt Vaca 441.7750 N6ICW Solano  CLOSED
# Fresno 441.8000 N6LYE Fresno  OPEN
# Napa 441.8000 W6CO Napa  OPEN
# San Leandro 441.8000 KQ6RC Alameda  CLOSED
# Concord 441.8250 WB6BDD Contra Costa  CLOSED
# Livermore 441.8250 K6LRG Alameda  OPEN
# Palo Alto, Black Mountain 441.8500 K6OTR Santa Clara  OPEN
# Sacramento 441.8500 NA6DF Sacramento  OPEN
# San Jose 441.8500 KG6KCL Santa Clara  CLOSED
# Dixon 441.8875 K6JWN Solano  OPEN
# Kensington 441.8875 AH6KD Contra Costa  OPEN
# Coalinga, Santa Rita Peak 441.9000 N6OA Fresno  OPEN
# Hollister 441.9000 W6MOW San Benito  OPEN
# Napa, Mt St Helena 441.9000 W6CO Sonoma  OPEN
# Aptos 441.9250 WA6HHQ Santa Cruz  OPEN
# Twain Harte 441.9250 W6YOP Tuolumne  OPEN
# Vacaville 441.9250 W6YOP Solano  CLOSED
# Sacramento 441.9500 K6YC Sacramento  OPEN
# San Jose 441.9500 N6MPX Santa Clara  OPEN
# Saratoga, Saratoga Heights 441.9500 KK6USZ Santa Clara  OPEN
# Orinda 441.9750 W6CBS Contra Costa  OPEN
# Springville, Blue Ridge 441.9750 KE6WDX Tulare  OPEN
# Vacaville 441.9750 W6RCA Solano  OPEN
# Eureka, Horse Mountain 442.0000 AE6R Humboldt  OPEN
# Palo Alto 442.0000 WW6HP Santa Clara  OPEN
# Rocklin 442.0000 N6UG Placer  OPEN
# Lemoore 442.0250 N6BEN Kings  OPEN
# Milpitas 442.0250 W6KCS Santa Clara  OPEN
# Salinas 442.0250 N6LEX Monterey  OPEN
# Santa Clara 442.0250 K6SNC Santa Clara  OPEN
# Vacaville 442.0250 W6KCS Solano  OPEN
# Geyserville 442.0500 WA6OYK Sonoma  OPEN
# San Francisco, Twin Peaks 442.0500 WA6GG San Francisco  OPEN
# Shingle Springs, Mt Aukum 442.0500 NC6R El Dorado  OPEN
# Greenfield, Vaquero Creek/Arroyo Seco  442.0750 K6LNK Monterey  OPEN
# Gualala 442.0750 K6LNK Mendocino  OPEN
# Meyers 442.0750 K6LNK El Dorado  OPEN
# Modesto, Mt Oso 442.0750 N6QOP Stanislaus  OPEN
# Pleasanton 442.0750 K6LNK Alameda  OPEN
# San Francisco, Downtown 442.0750 N6MVT San Francisco  OPEN
# Shasta Lake 442.0750 K7JKL Shasta  OPEN
# Millbrae 442.1000 K6HSV San Mateo  OPEN
# Willits, Laughlin Ridge 442.1000 K7WWA Mendocino  OPEN
# Santa Rosa 442.1125 K6ACS Sonoma  OPEN
# Palo Alto, Black Mountain 442.1250 W6PMI Santa Clara  CLOSED
# Rocklin 442.1250 N6UG Placer  OPEN
# Grass Valley 442.1500 AB6LI Nevada  OPEN
# Richmond 442.1500 WA6DUR Contra Costa  OPEN
# Campbell, Crystal Peak 442.1750 K9GVF Santa Clara  OPEN
# Fresno 442.1750 K6ACR Fresno  OPEN
# Lakehead 442.1750 KH8AF Shasta  CLOSED
# Oroville, Downtown 442.1750 WA6CAL Butte  OPEN
# San Jose 442.1750 N1UFD Santa Clara  CLOSED
# San Rafael 442.1750 KH8AF Marin  CLOSED
# Tahoe City 442.1750 KH8AF Placer  CLOSED
# Turlock 442.1750 WB6PBN Stanislaus  OPEN
# Oakland 442.2000 KH8AF Alameda  CLOSED
# Eureka 442.2250 WA6RQX Humboldt  CLOSED
# Monterey 442.2250 WH6KA Monterey  CLOSED
# Vacaville 442.2250 KH8AF Solano  CLOSED
# Fiddletown 442.2500 W6SF Amador  OPEN
# Napa 442.2500 N6TKW Napa  OPEN
# Oakland, Oakland Hills 442.2500 KD6QDW Alameda  OPEN
# Berkeley 442.2750 WA6ZTY Alameda  OPEN
# Maxwell, Coast Range foothills 442.2750 N6NMZ Colusa  OPEN
# Porterville 442.2750 AC6KT Tulare  OPEN
# Stockton 442.2750 K6GTO San Joaquin  OPEN
# Fresno 442.2875 WX6D Fresno  OPEN
# Visalia, Bear Mountain 442.2875 WX6D Tulare  OPEN
# San Jose 442.3000 K6INC Santa Clara  OPEN
# San Luis Obispo, Cal Poly 442.3000 W6BHZ San Luis Obispo  OPEN
# Vacaville 442.3000 W6NQJ Solano  CLOSED
# Visalia 442.3000 K6VIS Tulare  OPEN
# Visalia, Bear Mountain 442.3125 WX6D Tulare  OPEN
# Pescadero 442.3250 N6QZH San Mateo  CLOSED
# Sacramento 442.3250 KF6BIK Sacramento  CLOSED
# Sebastopol 442.3250 N6AMG Sonoma  CLOSED
# Visalia, Bear Mountain 442.3250 WX6D Tulare  OPEN
# Alturas, Likely Mountain 442.3500 WB6HMD Modoc  OPEN
# Cupertino 442.3500 K6GOD Santa Clara  CLOSED
# Folsom 442.3500 KS6HRP Sacramento  OPEN
# Hayward 442.3500 K6GOD Alameda  CLOSED
# Mariposa 442.3500 N6IB Mariposa  OPEN
# Milpitas 442.3500 K6GOD Santa Clara  OPEN
# Oroville 442.3500 WA6UHF Butte  OPEN
# Chico 442.3750 W6ECE Butte  OPEN
# Copperopolis 442.3750 N6MAC Calaveras  CLOSED
# Daly City 442.3750 K6JDE San Mateo  OPEN
# Daly City 442.3750 KC6PGV San Mateo  OPEN
# Merced 442.4000 KF6FM Merced  PRIVATE
# Oakland 442.4000 WB6NDJ Alameda  OPEN
# Red Bluff 442.4000 W6QWN Tehama  OPEN
# Sacramento 442.4000 WB6GWZ Sacramento  CLOSED
# Coalinga 442.4250 KF6FM Fresno  PRIVATE
# Grass Valley 442.4250 KF6GLZ Nevada  CLOSED
# San Jose, Regional Medical Center  442.4250 W6UU Santa Clara  OPEN
# Vallejo 442.4250 K6LI Solano  OPEN
# Concord 442.4500 KI6O Contra Costa  CLOSED
# Moraga 442.4500 KI6O Contra Costa  CLOSED
# Palo Alto 442.4500 KJ6VU Alameda  CLOSED
# San Jose 442.4500 WB6KHP Santa Clara  OPEN
# Daly City 442.4750 KF6REK San Mateo  OPEN
# Placerville 442.4750 WA6BTH El Dorado  OPEN
# Pollock Pines 442.4750 WA6KQV El Dorado  OPEN
# Sonora 442.4750 KJ6NRO Tuolumne  OPEN
# South Lake Tahoe 442.4750 WA6EWV El Dorado  OPEN
# Sacramento 442.5000 WA6ZZK Sacramento  OPEN
# San Jose 442.5000 WB6ZVW Santa Clara  OPEN
# Mountain View 442.5125 K6HLE Santa Clara  OPEN
# Crescent City 442.5250 KA7PRR Del Norte  CLOSED
# Folsom 442.5250 K6MFM Sacramento  OPEN
# Fresno 442.5250 N6IB Fresno  OPEN
# Sausalito, Wolfback Rdg 442.5250 K6ER Marin  OPEN
# Walnut Creek 442.5250 K6MFM Contra Costa  OPEN
# San Jose, Mount Umunhum 442.5375 WA6YCZ Santa Clara  OPEN
# Costa Mesa, John Wayne Airport 442.5500 KG6LEL Orange  OPEN
# Fremont, Mt Allison 442.5500 WA6FUL Santa Clara  CLOSED
# Modesto 442.5500 N6APB Stanislaus  CLOSED
# Santa Cruz , Near Loma Prieta  442.5500 WA6FUL Santa Cruz  CLOSED
# Vacaville 442.5500 N6APB Solano  CLOSED
# Meadow Lakes 442.5750 WX6D Nevada  OPEN
# Palo Alto, Black Mountain 442.5750 K6FB Santa Clara  OPEN
# Roseville 442.5750 KD6PDD Placer  OPEN
# Fremont 442.6000 WA6PWW Alameda  OPEN
# Sacramento 442.6000 N6NA Sacramento  OPEN
# Salinas 442.6000 KG6UYZ Monterey  OPEN
# Grass Valley 442.6250 W6AI Nevada  CLOSED
# Pleasanton 442.6250 W6SRR Alameda  OPEN
# Concord 442.6500 WA6ZTY Contra Costa  OPEN
# Berkeley 442.6750 WB6UZX Alameda  CLOSED
# Mariposa, Mt Bullion 442.6750 KI6HHU Mariposa  OPEN
# Foresthill 442.7000 KA6ZRJ Placer  OPEN
# San Jose 442.7000 N6MNV Santa Clara  OPEN
# San Luis Obispo, Cuesta Peak 442.7000 W6SLO San Luis Obispo  OPEN
# South San Francisco 442.7000 N6MNV San Francisco  OPEN
# Berkeley, Grizzly Peak 442.7250 K6DJR Alameda  CLOSED
# Benicia 442.7500 KR6BEN Solano  OPEN
# Daly City 442.7500 W6BUR San Mateo  OPEN
# Santa Cruz, Empire Grade 442.7500 W6DXW Santa Cruz  OPEN
# Fairfield 442.7750 KC6UJM Solano  OPEN
# Prunedale 442.7750 W6DXW Monterey  OPEN
# Quincy 442.7750 KF6CCP Plumas  OPEN
# San Jose 442.7750 KU6V Santa Clara  OPEN
# San Leandro 442.7750 KB6NCL Alameda  CLOSED
# Palo Alto 442.8000 K6OTR Santa Clara  OPEN
# Sacramento 442.8000 W6AK Sacramento  OPEN
# Clearlake 442.8250 WR6COP Lake  CLOSED
# San Jose 442.8250 WR6COP Santa Clara  CLOSED
# South Lake Tahoe, Heavenly Valley Ski area California base facility 442.8250 W6SUV El Dorado  OPEN
# Redding 442.8500 WR6TV Shasta  CLOSED
# San Jose 442.8500 WA6MIA Santa Clara  OPEN
# Vacaville 442.8500 AB6CQ Solano  OPEN
# Cobb 442.8750 KE6QDW Lake  OPEN
# Foresthill 442.8750 KA6EBR Placer  OPEN
# Hayward 442.8750 K6DDR Alameda  OPEN
# San Jose 442.8750 WA6YLV Santa Clara  OPEN
# San Luis Obispo 442.8750 WB6FMC San Luis Obispo  CLOSED
# Coarsegold 442.9000 W6HMH Madera  OPEN
# Sacramento 442.9000 K6NP Sacramento  OPEN
# San Jose, Loma Prieta 442.9000 K6JSI Santa Clara  OPEN
# Pleasanton 442.9250 W6RGG Alameda  CLOSED
# Tehachapi 442.9250  Kern  OPEN
# Grass Valley 442.9500 N6VYQ Nevada  OPEN
# San Jose 442.9500 K6YZS Santa Clara  OPEN
# Sequoia, Buck Rock 442.9500 KK6AC Fresno  OPEN
# Tahoe City 442.9500 WA6FJS Placer  OPEN
# Auburn 442.9625 NG6DNG Placer  OPEN
# Morgan Hill, Henry Coe Park 442.9750 K7DAA Santa Clara  OPEN
# Sonora, Downtown 442.9750 KJ6NRO Tuolumne  OPEN
# Vacaville 442.9750 K6JJC Solano  OPEN
# Bakersfield, Shirley Peak 443.0000 KI6HHU Kern  OPEN
# Laytonville, Cahto Peak 443.0000 K6JSI Mendocino  OPEN
# Palo Alto 443.0000 W6OOL Santa Clara  CLOSED
# Grass Valley 443.0250 WA6WER Nevada  OPEN
# Los Gatos 443.0250 WA6ABB Santa Clara  CLOSED
# Manteca 443.0250 KM6IRY San Joaquin  OPEN
# Milpitas 443.0250 K6EXE Santa Clara  CLOSED
# Susanville, Shaffer Mountain 443.0250 K6LRC Lassen  OPEN
# Susanville, Inspiration Pt 443.0250 K6LRC Lassen  OPEN
# Visalia 443.0250 WA6BLB Tulare  OPEN
# Crescent City 443.0500 KD6GDZ Del Norte  OPEN
# Orinda, Grizzly Peak 443.0500 N6QOP Contra Costa  OPEN
# Porterville 443.0500 KE6WDX Tulare  OPEN
# Redding 443.0500 WR6TV Shasta  OPEN
# Watsonville, Watsonville Community Hospital  443.0500 K6RMW Santa Cruz  OPEN
# Pleasanton 443.0625 N6LDJ Alameda  OPEN
# Walnut Creek 443.0625 K6LNK Contra Costa  OPEN
# Maricopa, Cerro Noroeste 443.0750 KC6WRD Kern  OPEN
# Mariposa, Mt Bullion 443.0750 K6IXA Mariposa  OPEN
# San Jose 443.0750 N6MVT Santa Clara  OPEN
# Stonyford 443.0750 N6MVT Colusa  OPEN
# Coalinga, Joaquin Ridge 443.1000 K6JSI Fresno  CLOSED
# Red Bluff 443.1000 N6YCK Tehama  OPEN
# San Francisco 443.1000 W6TP San Francisco  OPEN
# Smith River 443.1000 K6SLS Del Norte  OPEN
# Stockton 443.1000 N6GVI San Joaquin  CLOSED
# Fresno 443.1250 N6PNZ Fresno  OPEN
# Saratoga 443.1250 K6BEN Santa Clara  CLOSED
# Stockton 443.1250 KI6KGN San Joaquin  OPEN
# Cupertino 443.1500 NU6P Santa Clara  CLOSED
# Los Banos 443.1500 AA6LB Merced  OPEN
# Georgetown 443.1750 K6IRC El Dorado  CLOSED
# Modesto 443.1750 K6JJC Stanislaus  OPEN
# Pacifica 443.1750 K6PEG San Mateo  CLOSED
# Oakland 443.2000 N6GVI Alameda  CLOSED
# Visalia, Blue Ridge 443.2000 KM6OR Tulare  OPEN
# Lincoln 443.2250 W6LHR Placer  OPEN
# Palo Alto 443.2250 KJ6K Santa Clara  CLOSED
# Palo Alto, Black Mountain 443.2250 WW6BAY Santa Clara  OPEN
# Fresno 443.2500 WQ6CWA Fresno  OPEN
# Mill Valley, Mt Tamalpais 443.2500 K6GWE Marin  OPEN
# Scotia 443.2500 K6FWR Humboldt  OPEN
# Bakersfield 443.2750 N7BJD Kern  OPEN
# Bakersfield 443.2750 N7BJD Kern  OPEN
# Lompoc 443.2750 K7AZ Santa Barbara  OPEN
# Mcfarland 443.2750 N6RDN Kern  OPEN
# Sacramento 443.2750 KJ6JD Sacramento  CLOSED
# San Jose 443.2750 W6AMT Santa Clara  OPEN
# Centerville, Bear Mountain 443.3000 N6LYE Fresno  OPEN
# San Jose 443.3000 KB5JR Santa Clara  OPEN
# Madera 443.3125 N6LYE Madera  OPEN
# Berkeley 443.3250 WB6JKV Alameda  OPEN
# Coalinga 443.3250 K6JJC Fresno  OPEN
# Marysville 443.3250 K6JJC Yuba  OPEN
# Oakland 443.3500 AC6OT Alameda  OPEN
# San Andreas 443.3500 NC6R Calaveras  OPEN
# Visalia 443.3500 WA6YLB Tulare  OPEN
# Watsonville 443.3500 KB6MET Santa Cruz  OPEN
# Fresno 443.3750 KE6JZ Fresno  OPEN
# Oakland 443.3750 WB6SHU Alameda  OPEN
# San Leandro 443.3750 K6KBL Alameda  OPEN
# Fairfield 443.4000 WL3DZ Solano  CLOSED
# Fremont 443.4000 N6IGF Alameda  CLOSED
# Fresno 443.4000 NA6MM Fresno  CLOSED
# Milpitas 443.4000 WA6KPX Santa Clara  OPEN
# Fresno 443.4250 W6WYT Fresno  OPEN
# Moraga 443.4250 KB7IP Contra Costa  CLOSED
# Sebastopol 443.4250 WA6FUL Sonoma  OPEN
# Galt 443.4500 K6SAL Sacramento  OPEN
# Sacramento 443.4500 N0RM Sacramento  CLOSED
# San Jose 443.4500 K6MF Santa Clara  CLOSED
# Cisco Grove, Cisco Butte 443.4750 N6MVT Placer  OPEN
# Oakland 443.4750 N6QOP Alameda  OPEN
# San Jose, Mt Umunhum  443.4750 K6LNK Santa Clara  OPEN
# Santa Cruz 443.4750 WB6PHE Santa Cruz  OPEN
# Sonora 443.4750 K6LNK Tuolumne  OPEN
# Walnut Creek 443.4750 N6MVT Contra Costa  OPEN
# Coalinga, Joaquin Ridge 443.5000 N6LYE Kings  OPEN
# Concord 443.5000 K6JJC Contra Costa  CLOSED
# San Luis Obispo, Tassajara Peak 443.5000 K6LNK San Luis Obispo  OPEN
# Sunol 443.5125 W6SRR Alameda  OPEN
# Gilroy, Christmas Hill Park 443.5250 KJ6WZS Santa Clara  OPEN
# Modesto, Mt Oso 443.5250 K6JSI Stanislaus  OPEN
# San Rafael, San Pedro Ridge 443.5250 K6GWE Marin  OPEN
# Georgetown 443.5500 K6SRA El Dorado  CLOSED
# San Jose 443.5500 K6TAZ Santa Clara  CLOSED
# Concord 443.5750 K6IRC Contra Costa  CLOSED
# San Jose 443.5750 KE6STH Santa Clara  OPEN
# San Luis Obispo 443.5750 W6FM San Luis Obispo  CLOSED
# Auberry 443.6000 N6LYE Fresno  OPEN
# Auburn 443.6000 N6LYE Placer  OPEN
# Fresno, Bear Mountain 443.6000 W6FSC Fresno  OPEN
# Hollister 443.6000 W6MOW San Benito  OPEN
# Novato 443.6000 KI6B Marin  CLOSED
# Palo Alto, Gunn High School 443.6000 KK6KPQ Santa Clara  PRIVATE
# Pioneer 443.6250 K6MSR Amador  CLOSED
# San Jose 443.6250 K6MSR Santa Clara  CLOSED
# Westley 443.6250 K6MSR Stanislaus  CLOSED
# Fresno 443.6500 KE6SHK Fresno  OPEN
# Grass Valley 443.6500 KG6BAJ Nevada  OPEN
# Monterey 443.6500 N6AMO Monterey  OPEN
# Pleasanton 443.6500 K6TEA Alameda  CLOSED
# Los Altos 443.6750 K6MSR Santa Clara  CLOSED
# San Francisco 443.6750 K6MSR San Francisco  CLOSED
# Corcoran, Castle Peak 443.7000 AA6GZ Fresno  OPEN
# Fremont 443.7000 K6JJC Alameda  OPEN
# Walnut Grove 443.7000 WA6JIV Sacramento  CLOSED
# Coalinga, Joaquin Ridge 443.7250 K6NOX Fresno  OPEN
# Coalinga, Joaquin Ridge 443.7250 N6LYE Fresno  OPEN
# Fremont, Mt Allison 443.7250 N6HWI Alameda  OPEN
# Los Gatos 443.7500 K9GVF Santa Clara  OPEN
# Silicon Valley 443.7500 KA6DWN Santa Clara  OPEN
# Vacaville 443.7500 WA6KBP Solano  CLOSED
# Yreka 443.7500 K6SIS Siskiyou  OPEN
# Fresno 443.7750 KF6FGL Fresno  OPEN
# San Jose 443.7750 WA6GFY Santa Clara  OPEN
# Concord, Mt Diablo 443.8000 K6POU Contra Costa  OPEN
# Fresno 443.8000 KE6JZ Fresno  OPEN
# San Luis Obispo 443.8000 N6HYM San Luis Obispo  CLOSED
# Clovis 443.8250 N6IB Fresno  OPEN
# Oakland 443.8250 KB6FEC Amador  OPEN
# Orinda 443.8250 K6JJC Contra Costa  OPEN
# Santa Rosa 443.8250 WB7ABP Sonoma  OPEN
# Walnut Creek 443.8250 KK6BSN Contra Costa  OPEN
# Westley, Mt Oso 443.8250 K6JJC Stanislaus  OPEN
# Georgetown 443.8500 WA6APX El Dorado  CLOSED
# Los Altos Hills 443.8500 W6BUG Santa Clara  CLOSED
# Fiddletown 443.8750 K6SZQ Amador  OPEN
# Fresno 443.8750 KF6FGL Fresno  OPEN
# Oakland 443.8750 W6MTF Alameda  CLOSED
# Stonyford 443.8750 K6BIQ Colusa  OPEN
# Bakersfield 443.9000 W6LIE Kern  OPEN
# Prunedale 443.9000 W6TAR Monterey  OPEN
# Sacramento 443.9000 W6YDD Sacramento  OPEN
# San Jose, San Jose State Univ. 443.9000 W6YL Santa Clara  OPEN
# Susanville 443.9000 K6LRC Lassen  OPEN
# Placerville, El Dorado Hills 443.9250 N6QDY El Dorado  OPEN
# South San Francisco 443.9250 KG6TN San Francisco  OPEN
# Vacaville, Mt Vaca 443.9500 K6MVR Napa  OPEN
# Arroyo Grande, Lopez Hill 443.9750 W6YDZ San Luis Obispo  OPEN
# Fresno 443.9750 K6SRA Fresno  CLOSED
# King City 443.9750 K6TAZ Monterey  CLOSED
# Oakland 443.9750 WW6BAY Alameda  OPEN
# Tahoe City 443.9750 K6SRA Placer  CLOSED
# Cazadero 444.0000 K6CHG Sonoma  OPEN
# Los Banos 444.0000 K6TJS Merced  OPEN
# Modesto, Mt Oso 444.0000 K6TJS Stanislaus  OPEN
# Orinda 444.0000 KE6PTT Contra Costa  OPEN
# Santa Cruz 444.0000  Santa Cruz  OPEN
# Scotts Valley 444.0000 W6WLS Santa Cruz  OPEN
# Georgetown 444.0250 K6JJC El Dorado  OPEN
# San Jose 444.0250 K6JJC Santa Clara  OPEN
# San Jose, Loma Prieta 444.0250 K6HLE Santa Clara  OPEN
# Upper Lake 444.0250 KJ6IFS Lake  OPEN
# San Jose 444.0375 K6HLE Santa Clara  OPEN
# Sonoma, Sonoma Mountain 444.0375 NN6J Sonoma  OPEN
# Timber Cove 444.0375 K6CHG Sonoma  OPEN
# Timber Cove 444.0375 K6CHG Sonoma  OPEN
# Grass Valley 444.0500 K6NP Nevada  OPEN
# San Jose 444.0500 KD6CUC Santa Clara  CLOSED
# Diamond Springs 444.0750 WA6EUZ El Dorado  CLOSED
# King City 444.0750 WB6ORK Monterey  OPEN
# Palo Alto, Black Mountain 444.0750 WW6BAY Santa Clara  OPEN
# Fresno, Meadow Lakes 444.1000 W6NIF Fresno  OPEN
# Morgan Hill 444.1000 KC6WTF Santa Clara  OPEN
# San Jose 444.1000 N6TLQ Santa Clara  CLOSED
# San Luis Obispo, Tassajara Peak 444.1000 W6SLO San Luis Obispo  OPEN
# San Simeon, Rocky Butte 444.1000 W6SLO San Luis Obispo  OPEN
# Cohasset 444.1250 KH8AF Butte  CLOSED
# Fairfield 444.1250 KE3RQ Solano  CLOSED
# Livermore 444.1250 K7FED Alameda  OPEN
# Los Gatos 444.1250 WB6LPZ Santa Clara  CLOSED
# Vacaville 444.1250 W6SEL Solano  CLOSED
# Calistoga 444.1500 N6PMF Napa  CLOSED
# Newark 444.1500 N3EL Alameda  OPEN
# Red Bluff 444.1500 KH8AF Tehama  CLOSED
# Calistoga 444.1750 N6TKW Napa  OPEN
# San Jose 444.1750 WA6RQX Santa Clara  OPEN
# San Miguel 444.1750 KB6CIO San Luis Obispo  OPEN
# Westley 444.1750 WA6RQX Stanislaus  OPEN
# Elk Creek 444.2000 K6BIQ Glenn  OPEN
# Fresno 444.2000 W6TO Fresno  OPEN
# San Leandro 444.2000 W6RGG Alameda  OPEN
# Lodi 444.2250 N6GKJ San Joaquin  OPEN
# Los Altos Hills 444.2250 KE6JTK Santa Clara  OPEN
# Petaluma 444.2250 NI6B Sonoma  CLOSED
# San Francisco , VA Hospital 444.2250 W6PW San Francisco  OPEN
# Alturas 444.2500 N6KMR Modoc  OPEN
# Lodi 444.2500 WB6ASU San Joaquin  OPEN
# Meadow Lakes 444.2500 K6JSI Fresno  OPEN
# Oakland, Oakland Hills 444.2500 WB6TCS Alameda  OPEN
# Auberry 444.2750 KG6IBA Fresno  OPEN
# King City, Williams Hill 444.2750 WA6VPL Monterey  CLOSED
# Lompoc, Vandenberg AFB 444.2750 WA6VPL Santa Barbara  OPEN
# Monterey 444.2750 N6SPD Monterey  OPEN
# Oroville 444.2750 KJ6LVV Butte  OPEN
# Pleasanton 444.2750 N6LDJ Alameda  OPEN
# San Pablo 444.2750 WA6KQB Contra Costa  OPEN
# Truckee 444.2750 WA6JQV Nevada  CLOSED
# Dobbins 444.3000 N6ICW Yuba  CLOSED
# San Jose 444.3000 WB6RNH Santa Clara  OPEN
# San Jose 444.3000 WB6RNH Santa Clara  OPEN
# Redding, Shasta Bally 444.3250 AB7BS Shasta  OPEN
# San Jose 444.3250 KD6AOG Santa Clara  OPEN
# Stockton 444.3250 WA6TCG San Joaquin  OPEN
# Mt Shasta City 444.3500 K6PRN Siskiyou  CLOSED
# Palo Alto, Black Mountain 444.3500 WW6BAY Santa Clara  OPEN
# San Luis Obispo 444.3500 K6DOA San Luis Obispo  OPEN
# Turlock 444.3500 W6BXN Stanislaus  OPEN
# Coarsegold, Trabuco Mountain 444.3750 K6MXZ Madera  OPEN
# Santa Rosa 444.3750 WB6RUT Sonoma  CLOSED
# Soledad 444.3750 WA6RQX Monterey  OPEN
# Chico 444.4000 KE6ADC Butte  OPEN
# Coarsegold 444.4000 KE6YMW Madera  OPEN
# Copperopolis, Gopher Ridge 444.4000 N6GKJ Calaveras  OPEN
# San Jose, Mt Umunhum 444.4000 WA6YCZ Santa Clara  CLOSED
# Bakersfield, Cummings Mountain 444.4250 KG6KKV Kern  OPEN
# Palo Alto, Black Mtn 444.4250 WW6BAY Santa Clara  OPEN
# Sacramento 444.4250 K6PRN Sacramento  CLOSED
# Yreka 444.4250 K6PRN Siskiyou  CLOSED
# Martinez 444.4500 N6YJ Contra Costa  OPEN
# San Jose 444.4500 WB6JSO Santa Clara  OPEN
# Visalia 444.4500 WA6MSN Tulare  OPEN
# Auburn, Stony Ridge 444.4750 K6IOK Placer  OPEN
# Calistoga 444.4750 K6IRC Napa  CLOSED
# Monterey 444.4750 N6AMO Monterey  CLOSED
# Mt Shasta City, Mt Bradley 444.4750 AB7BS Siskiyou  OPEN
# San Jose 444.4750 W6OTX Santa Clara  OPEN
# San Luis Obispo 444.4750 W6FM San Luis Obispo  PRIVATE
# Auburn  444.5000 K6IOK Placer  OPEN
# Chester 444.5000 KF6CCP Plumas  OPEN
# Coarsegold 444.5000 WB6NIL Madera  OPEN
# Redwood City 444.5000 K6MPN San Mateo  OPEN
# Stockton, Coronado Tower 444.5000 K6TRK San Joaquin  OPEN
# Merced 444.5250 W6TCD Merced  OPEN
# Monterey 444.5250 N6GAI Monterey  OPEN
# Napa 444.5250 K6ZRX Napa  OPEN
# Salinas, Laguna Seca 444.5250 W6JSO Monterey  OPEN
# San Luis Obispo, Tassajara Peak 444.5250 W6FM San Luis Obispo  OPEN
# Vacaville 444.5250 AA6GV Solano  CLOSED
# King City 444.5500 W6FM Monterey  CLOSED
# Redding, South Fork Mountain 444.5500 NC6SV Shasta  OPEN
# Sausalito 444.5500 WA6EUZ Marin  CLOSED
# Sunnyvale 444.5500 AF6EQ Santa Clara  OPEN
# Alameda, Alameda Hospital 444.5750 K6QLF Alameda  OPEN
# Mojave 444.5750 WA6CAM Kern  OPEN
# Rosamond, Taco Bell 444.5750 WA6CAM Kern  OPEN
# Susanville 444.5750 KE6NDG Lassen  OPEN
# Vacaville, Mt Vaca 444.5750 WA6EUZ Solano  CLOSED
# Auburn 444.6000 N6NMZ Placer  OPEN
# Bishop, Silver Peak 444.6000 W6IY Inyo  OPEN
# Kingsburg 444.6000 KB6RHD Fresno  OPEN
# Pacific Grove, Forest Hill 444.6000 K6CQX Monterey  OPEN
# Pismo Beach 444.6000 KB6BF San Luis Obispo  OPEN
# San Jose 444.6000 WB6OQS Santa Clara  OPEN
# Redding 444.6250 KD6NOL Shasta  OPEN
# Sacramento 444.6250 K6RAK Sacramento  OPEN
# San Jose 444.6250 N6NAC Santa Clara  OPEN
# Burney, Hatchet Mountain 444.6500 KE6CHO Shasta  OPEN
# Oakland 444.6500 W6PUE Alameda  CLOSED
# Redding 444.6500 KD6LOM Shasta  OPEN
# Sonora 444.6500 K6KVA Tuolumne  OPEN
# Hanford 444.6600 W6FBW Kings  OPEN
# Bakersfield 444.6750 KG6FOS Kern  OPEN
# Canby 444.6750 K6PRN Modoc  OPEN
# Mill Valley, Mt Tamalpais 444.6750 KJ6RA Marin  CLOSED
# El Cerrito 444.7000 N6GVI Contra Costa  CLOSED
# Mariposa, Mt Bullion 444.7000 W6BXN Mariposa  OPEN
# Nipomo 444.7000 KB6Q San Luis Obispo  OPEN
# Pebble Beach, Huckleberry Hill 444.7000 K6LY Monterey  OPEN
# San Jose, Good Samaritan Hospital 444.7000 WB6KHP Santa Clara  OPEN
# Citrus Heights 444.7250 KA6FTY Sacramento  CLOSED
# Clovis, Mile High 444.7250 K6ARP Fresno  OPEN
# Mammoth Lakes, Mammoth Lakes 444.7250 WA6TTL Mono  PRIVATE
# Milpitas, Mission Peak 444.7250 K6GOD Santa Clara  CLOSED
# San Francisco 444.7250  San Francisco  OPEN
# Yountville, Mt Veeder 444.7250 N6TKW Napa  OPEN
# Bakersfield 444.7500 N6SMU Kern  OPEN
# Eureka, Bunker Hill 444.7500 WA6RQX Humboldt  CLOSED
# Grass Valley 444.7500 K6RTL Nevada  OPEN
# San Jose 444.7500 N9JIM Santa Clara  OPEN
# Santa Rosa, Sanel Mountain 444.7500 WA6RQX Mendocino  OPEN
# Santa Rosa 444.7500 KD6RC Sonoma  OPEN
# Vacaville 444.7500 WA6RTL Solano  OPEN
# Oakland 444.7750 W6YOP Alameda  OPEN
# Susanville 444.7750 KE6NDG Lassen  OPEN
# Mariposa, Mt Bullion 444.7875 W6BXN Mariposa  OPEN
# Bishop 444.8000 WA6ZFT Inyo  OPEN
# Daly City 444.8000 WA6GEL San Mateo  CLOSED
# Fremont 444.8000 WA6GEL Alameda  CLOSED
# Laytonville 444.8000 WA6RQX Mendocino  CLOSED
# Lompoc 444.8000 WA6VPL Santa Barbara  CLOSED
# Mariposa 444.8000 W6HHD Mariposa  OPEN
# Oakland 444.8000 KD6GLT Alameda  CLOSED
# San Jose 444.8000 WA6GEL Santa Clara  CLOSED
# Stockton 444.8000 NV6RN San Joaquin  OPEN
# Crescent City 444.8250 KF6QBW Del Norte  OPEN
# Crescent City 444.8250 KF6QBW Del Norte  OPEN
# Dinuba 444.8250 N6SGW Tulare  OPEN
# Kelsey 444.8250 W6TIQ El Dorado  CLOSED
# Mt Shasta City 444.8250 AB6MF Siskiyou  OPEN
# Sebastopol 444.8250 WA6TIP Sonoma  OPEN
# Angels Camp 444.8500 N6LZR Calaveras  OPEN
# Hayward 444.8500 KB6LED Alameda  OPEN
# San Francisco 444.8500 K6KYA San Francisco  OPEN
# Vacaville 444.8500 W6PUE Solano  CLOSED
# Concord 444.8750 K6FJ Contra Costa  OPEN
# Susanville 444.8750 KE6NDG Lassen  OPEN
# San Jose, Santa Cruz Mountains 444.9000 KU6V Santa Clara  OPEN
# San Luis Obispo 444.9000 KC6WRD San Luis Obispo  CLOSED
# Santa Rosa 444.9000 KF6SZA Sonoma  OPEN
# Yreka 444.9000 AB6MF Siskiyou  OPEN
# Alleghany 444.9250 WR6ASF Sierra  OPEN
# Bakersfield 444.9250 K6RET Kern  OPEN
# Grass Valley 444.9250 AB6LI Nevada  OPEN
# Los Gatos 444.9250 KB6LCS Santa Clara  OPEN
# San Francisco 444.9250 KB6LCS San Francisco  OPEN
# Willits, Laughlin Ridge 444.9250 K7WWA Mendocino  OPEN
# San Luis Obispo 444.9375 KK6DJ San Luis Obispo  OPEN
# Auburn, Sugar Pine Ridge 444.9500 K6JSI Placer  CLOSED
# Hanford 444.9500 N6CVC Kings  OPEN
# Nevada City 444.9500 W6JP Nevada  OPEN
# Palo Alto 444.9500 KB6LED Santa Clara  OPEN
# Red Bluff 444.9500 W6QWN Tehama  OPEN
# Tahoe City 444.9500 W6PUE Placer  CLOSED
# Los Gatos, Santa Cruz Mountains 444.9750 WB6KHP Santa Clara  OPEN
# Los Osos, Clark Valley / Irish Hills 444.9750 W6SLO San Luis Obispo  OPEN
# Meadow Lakes 444.9750 W6BJ Fresno  OPEN
# Susanville, Inspiration Point 444.9750 K6ME Lassen  OPEN
# Sebastopol 444.9875 KC6SOT Sonoma  OPEN
# Sebastopol 444.9875 KC6SOT Sonoma  OPEN
# Tahoma, Spider Lake 444.9875  Placer  OPEN
# Cedarpines Park, Jobs Peak 445.0200 W6CDF San Bernardino  OPEN
# La Mesa 445.0200 WA6HYQ San Diego  CLOSED
# Sylmar, Contractors Pt 445.0400 K6HOG Los Angeles  OPEN
# Alhambra, Cal State LA 445.0600 KM6EON Los Angeles  OPEN
# Riverside 445.0600 KB6OZX Riverside  OPEN
# Diamond Bar 445.0800 NO6B Los Angeles  OPEN
# Temecula 445.0800 KE6UPI Riverside  OPEN
# Aliso Viejo 445.1000 KI6DB Orange  OPEN
# Chatsworth, Oat Mountain 445.1000 WB6NIL Los Angeles  OPEN
# Lake Arrowhead, Heaps Peak 445.1000 WW6Y San Bernardino  OPEN
# Fullerton, Fullerton Hills 445.1200 KK6HS Orange  PRIVATE
# Yucaipa, Little San Gorgonio Peak 445.1400 W6DXX San Bernardino  CLOSED
# Banning, Snow Peak 445.1600 W6CTR San Bernardino  OPEN
# Malibu, Saddle Peak 445.1800 WB6ZTR Los Angeles  PRIVATE
# Moreno Valley, Reche Peak 445.1800 KJ6QFS Riverside  PRIVATE
# La Canada, JPL (building) 445.2000 WR6JPL Los Angeles  OPEN
# Oceanside 445.2000 W6BJB San Diego  OPEN
# Pasadena, JPL Mesa 445.2000 WR6JPL Los Angeles  OPEN
# Alhambra 445.2200 WB6NIL Los Angeles  OPEN
# Corona 445.2200 KE6PCV Riverside  CLOSED
# Fallbrook, Red Mountain 445.2200 KF6ATL San Diego  PRIVATE
# Sun Valley 445.2200 KC6HUR Los Angeles  OPEN
# El Segundo 445.2400 WB6VMV Los Angeles  CLOSED
# Wrightwood 445.2400 KW6WW San Bernardino  OPEN
# Verdugo Peak, Verdugo Peak 445.2600 K6VGP Los Angeles  PRIVATE
# Palos Verdes, San Pedro Hill 445.2800 K6VGP Los Angeles  PRIVATE
# Orange, UCI Med Ctr 445.3000 WA6IGJ Orange  CLOSED
# Palos Verdes 445.3000 K6RH Los Angeles  OPEN
# Redlands 445.3000 AI6BX San Bernardino  OPEN
# Santa Clarita, Mad Mountain 445.3000 W6JW Los Angeles  OPEN
# Temecula 445.3000 W6CDF Riverside  OPEN
# Culver City, Baldwin Hills 445.3200 WA6MDJ Los Angeles  OPEN
# Redlands, Sunset Hills 445.3400 AI6BX San Bernardino  CLOSED
# Spring Valley, Dictionary Hill 445.3400 N6RVI San Diego  OPEN
# Sylmar, Contractors Point 445.3400 KC6JAR Los Angeles  OPEN
# Glendale, Flint Peak 445.3800 K6CCC Los Angeles  PRIVATE
# Moreno Valley, Box Springs 445.3800 WA6LSE Riverside  CLOSED
# Irvine, Signal Peak 445.4000 WD6DIH Orange  CLOSED
# Santa Monica, Saddle Peak 445.4200 WD6FZA Los Angeles  OPEN
# Pasadena, Mirador Peak 445.4400 W6UE Los Angeles  PRIVATE
# Chatsworth Peak 445.4600 K6LAM Ventura  CLOSED
# Lake Arrowhead 445.4600 NO6B San Bernardino  PRIVATE
# Arcadia, Santa Anita Ridge 445.4800 K6TEM Los Angeles  OPEN
# Palmdale, Hauser Peak 445.4800 N6ND Los Angeles  CLOSED
# Santa Barbara, La Vigia Hill 445.4800 K6TZ Santa Barbara  OPEN
# Arcadia, Santa Anita Ridge 445.5000 N6EX Los Angeles  CLOSED
# Buena Park, Knotts Berry Farm 445.5200 K6KBF Orange  OPEN
# Pacific Palisades 445.5200 K6BDE Los Angeles  OPEN
# Rialto, Fire station 445.5200 K6RIA San Bernardino  OPEN
# Altadena, Mt. Wilson 445.5400 WD6ABC Los Angeles  OPEN
# Chino 445.5600 K6OPJ San Bernardino  OPEN
# Ojai, Sulphur Mountain 445.5600 WD6EBY Ventura  OPEN
# Palomar Mountain, Palomar Observatory 445.5600 KI6AZQ San Diego  OPEN
# Quartz Hill, water tank 445.5600 KG6SLC Los Angeles  OPEN
# Whittier, Whittier Hills 445.5600 W6KAT Los Angeles  OPEN
# Huntington Beach, Boeing 445.5800 W6VLD Orange  OPEN
# Pomona 445.5800 K6CPP Los Angeles  OPEN
# Simi Valley, Mellow Lane 445.5800 K6ERN Ventura  OPEN
# Camarillo, Camarillo Hills 445.6000 WD6EBY Ventura  OPEN
# Culver City 445.6000 K6CCR Los Angeles  OPEN
# Fallbrook, Red Mountain 445.6000 N6FQ San Diego  OPEN
# Loma Linda, LLUMC 445.6000 K6LLU San Bernardino  OPEN
# Palmdale, Ten-Hi 445.6000 KJ6W Los Angeles  OPEN
# Ventura 445.6000 KB6LJQ Ventura  OPEN
# El Segundo, Raytheon 445.6200 W6HA Los Angeles  OPEN
# Lake Elsinore, Elsinore Peak 445.6200 W6CDW Riverside  OPEN
# Spring Valley, Dictionary Hill 445.6200 WA6NVL San Diego  OPEN
# Altadena 445.6400 W6TOI Los Angeles  OPEN
# Carpinteria, Rincon Mtn. 445.6400 WD6EBY Ventura  OPEN
# Frazier Park 445.6400 K6NYB Kern  OPEN
# Palm Springs, Indio Hills 445.6400 K6IFR Riverside  OPEN
# Downey 445.6600 K6EH Los Angeles  OPEN
# Laguna Beach, Temple Hill 445.6600 K6SOA Orange  OPEN
# Apple Valley 445.6800 KB6BZZ San Bernardino  OPEN
# Glendale, Mt Thom 445.6800 N6JLY Los Angeles  OPEN
# San Diego, Black Mtn 445.6800 N6DCR San Diego  OPEN
# Ojai, Sulphur Mountain 445.7000 N6BMW Ventura  OPEN
# Running Springs 445.7000 K6AMS San Bernardino  OPEN
# Laguna Beach, Temple Hill 445.7050 K6SOA Orange  OPEN
# Rancho Palos Verdes 445.7200 N6RPV Los Angeles  OPEN
# Santa Paula 445.7200 N6BMW Ventura  OPEN
# Ventura 445.7200 N6BMW Ventura  OPEN
# Agoura, Castro Peak 445.7400 K6JHX Los Angeles  CLOSED
# Channel Islands Harbor, Ventura 445.7600 KI6HHU Ventura  OPEN
# Corona, Sierra Peak 445.7600 KD6DDM Orange  OPEN
# Ramona 445.7600 KD6RSQ San Diego  OPEN
# Crestline 445.7800 K6PIN San Bernardino  CLOSED
# Altadena, Mt. Disappointment 445.8000 WA6IBL Los Angeles  CLOSED
# Chatsworth, Chatsworth Peak 445.8000 W6RRN Ventura  PRIVATE
# Santa Monica, Saddle Peak 445.8200 K6VGP Los Angeles  PRIVATE
# Chatsworth, Chatsworth Peak 445.8400 WD6EBY Ventura  OPEN
# Chino Hills 445.8400 W6AJP San Bernardino  CLOSED
# Leona Valley 445.8400 AF6TG Los Angeles  OPEN
# Escondido, Palomar Mountain 445.8600 WB6YES Riverside  OPEN
# Palomar, Palomar Mtn 445.8600 KI6MGN San Diego  CLOSED
# Upland 445.8600 K6PQN San Bernardino  CLOSED
# Escondido, Palomar Mountain 445.8650 KI6MGN San Diego  OPEN
# Chatsworth, Oat Mountain 445.8800 K7FY Los Angeles  CLOSED
# San Marcos 445.8800 AA4CD San Diego  OPEN
# Canyon Country 445.9000 KC6TKA Los Angeles  OPEN
# El Cajon 445.9000 WA6BGS San Diego  OPEN
# Irvine 445.9000 KC4OGF Orange  OPEN
# Phelan 445.9000 N6RPG San Bernardino  OPEN
# Rosemead 445.9000 KA6GXY Los Angeles  OPEN
# Claremont, Sunset Ridge 445.9200 KD6AFA Los Angeles  OPEN
# Hagador Peak 445.9400 W6CTR San Bernardino  OPEN
# Rancho Palos Verdes 445.9800 WZ6A Los Angeles  CLOSED
# San Dimas, Johnstone Peak 446.0200 W6FNO Los Angeles  CLOSED
# Pomona, Sunset Ridge 446.0400 KF6FM Los Angeles  PRIVATE
# Blythe 446.0500 K6JRM Riverside  OPEN
# Redondo Beach 446.0500 W6TRW Los Angeles  OPEN
# Crestline, Strawberry Peak 446.0600 KF6FM San Bernardino  PRIVATE
# Downey 446.0600 K6EH Los Angeles  OPEN
# Pine Cove 446.0600  Riverside  OPEN
# Rancho Palos Verdes 446.0600  Los Angeles  PRIVATE
# Victorville, Quartzite Mtn  446.0600 N6GGS San Bernardino  OPEN
# Cactus City 446.0625 WD6AML Riverside  OPEN
# El Cajon 446.0625 W6HDC San Diego  OPEN
# Pine Cove 446.0625 K6TMD Riverside  OPEN
# Victorville, Table Mtn 446.0625 N6GGS Riverside  OPEN
# Pasadena, Mt. Wilson 446.1000 N6LXX Los Angeles  CLOSED
# San Diego, Mt San Miguel 446.1000 N6LXX San Diego  CLOSED
# Victorville, Quartzite Mountain 446.1000 WR6QZ San Bernardino  CLOSED
# Lake Forest, Santiago Peak 446.1200 WB6MIE Orange  PRIVATE
# Avalon, Buena Vista Pt. 446.1400 AA6DP Los Angeles  OPEN
# Orange 446.1400 KB6CJZ Orange  CLOSED
# San Diego 446.1400 W6SS San Diego  OPEN
# Pomona, ACS Enterprises, Inc. 446.1600 KC6ACS Los Angeles  OPEN
# San Diego, Rattlesnake Peak 446.1800 N6JOJ San Diego  PRIVATE
# Big Bear, E. of Snow Summit 446.2000 K6BB San Bernardino  OPEN
# Santa Barbara, La Cumbre Peak 446.2000 WA6TTL Santa Barbara  PRIVATE
# Glendale, Mt Lukens 446.2200 KI6QK Los Angeles  CLOSED
# Lake Forest, Santiago Peak 446.2200 KI6QK Orange  CLOSED
# Altadena, Mt Disappointment 446.2400 K6VGP Los Angeles  PRIVATE
# Hollywood, Hollywood Hills 446.2800 WB6BJM Los Angeles  PRIVATE
# Rowland Heights 446.2800 NO6B Los Angeles  PRIVATE
# Woodside 446.2800 KF6JEE San Mateo  PRIVATE
# Calico 446.3000 WR6CM San Bernardino  CLOSED
# Lake Forest, Santiago Peak 446.3000 N6SIM Orange  CLOSED
# Vista 446.3000 KA3AJM San Diego  PRIVATE
# Lake Forest, Santiago Peak 446.3200 WA6TWF Orange  CLOSED
# Ventura, Red Mtn. 446.3250 WA6UEO Ventura  OPEN
# Running Springs , Keller Peak 446.3400 KI6WZX San Bernardino  OPEN
# Anza, Toro Peak 446.3800 WD6FZA Riverside  CLOSED
# Baker, Halloran Summit 446.3800 WR6TM San Bernardino  CLOSED
# Chatsworth, Chatsworth Peak 446.3800 W6KGB Ventura  PRIVATE
# Lake Forest, Santiago Peak 446.3800 KD6KQ Orange  CLOSED
# Big Bear City 446.4000 WA6ITC San Bernardino  OPEN
# Quartz Hill 446.4000 KD6PXZ Los Angeles  OPEN
# San Dimas, Johnstone Peak 446.4000 WA6FZH Los Angeles  OPEN
# Santa Barbara, La Vigia Hill 446.4000 K6TZ Santa Barbara  OPEN
# Seal Beach 446.4000 WA6FZH Los Angeles  OPEN
# Big Bear City 446.4200 WA6ITC San Bernardino  CLOSED
# Hemet, Highway 74 446.4200 KK6SMA Riverside  OPEN
# Moreno Valley 446.4200 KK6SMA Riverside  OPEN
# Mt Laguna, Stephenson Pk 446.4200 K6KTA San Diego  OPEN
# Santa Monica, Saddle Peak 446.4200 W6YJ Los Angeles  PRIVATE
# Fullerton, Raytheon Bldg 606 446.4400 K6QEH Orange  CLOSED
# Chatsworth, Oat Mountain 446.4600 K6JSI Los Angeles  OPEN
# Brea, Brea Civic Center 446.5400 WB6DNX Orange  CLOSED
# Yorba Linda 446.5400 N6MIK Orange  OPEN
# Hollywood 446.5600 WD8CIK Los Angeles  OPEN
# Palm Springs, Edom Hill 446.5800 K6IFR Riverside  OPEN
# San Marcos 446.5800 WD6FZA San Diego  OPEN
# Murrieta , Loma Linda Hospital  446.6000 W6GTR Riverside  OPEN
# Santa Cruz Island, Diablo Peak 446.6000 W6KGB Santa Barbara  PRIVATE
# San Fernando, Loop Canyon 446.6200 WA6TTL Los Angeles  PRIVATE
# Lake Forest, Santiago Peak 446.6400 KF6PHX Orange  OPEN
# Chatsworth, Chatsworth Peak 446.6600 WA6TTL Los Angeles  PRIVATE
# Chatsworth, Oat Mountain 446.6800 WA6LWW Los Angeles  CLOSED
# Lake Forest, Santiago Peak 446.7000 WA6TWF Orange  CLOSED
# Escondido, Palomar Mountain 446.7200 KB6CRE San Diego  CLOSED
# Palmdale, Ten-Hi 446.7400 K6VGP Los Angeles  CLOSED
# Rancho Palos Verdes 446.7400 K6VGP Los Angeles  CLOSED
# San Diego, Mount Laguna 446.7500 KA6DAC San Diego  CLOSED
# Altadena, Mt Wilson 446.7800 WA6LWW Los Angeles  CLOSED
# Chatsworth, Oat Mountain 446.8000 N6LXX Los Angeles  CLOSED
# Fallbrook 446.8000 KG6HSQ San Diego  OPEN
# San Dimas, Johnstone Peak 446.8000 KM6RW Los Angeles  CLOSED
# Yermo 446.8000 N6LXX San Bernardino  OPEN
# Rancho Palos Verdes 446.8200 WA6LIF Los Angeles  CLOSED
# Lake Forest, Santiago Peak 446.8400 N6EHM Orange  CLOSED
# Avalon, Mt. Ada 446.8600 N6SCI Los Angeles  OPEN
# Carlsbad 446.8600 K6VST San Diego  OPEN
# Glendora 446.8600 KK6JYT Los Angeles  OPEN
# Hemet 446.8600 K6JRM Riverside  OPEN
# Oceanside 446.8600 N6TRI San Diego  OPEN
# San Diego, Sorrento Valley 446.8600 W6QAR San Diego  OPEN
# Wrightwood, Blue Ridge 446.8600 N6LXX Los Angeles  OPEN
# Wrightwood, Blue Ridge 446.8700 W6CPA Los Angeles  OPEN
# Alta Loma 446.8800 KJ6KTV San Bernardino  OPEN
# Hemet 446.8800 KB6JAG Riverside  OPEN
# La Mesa 446.8800 WA6ZFT San Diego  OPEN
# Mission Hills 446.8800 KJ6HVS Los Angeles  OPEN
# Onyx, Onyx Peak 446.8800 N6LXX San Bernardino  OPEN
# Irvine, Signal Peak 446.9000 WD6DIH Orange  PRIVATE
# Lake Forest, Santiago Peak 446.9000 WD6DIH Orange  CLOSED
# Altadena, Mt Wilson 446.9400  Los Angeles  PRIVATE
# Baker, Turquoise Mountain 446.9600 WD6DIH San Bernardino  PRIVATE
# Loop Canyon 446.9800 WA6WLZ Los Angeles  CLOSED
# Camarillo, Camarillo Springs 447.0000 K6ERN Ventura  OPEN
# Escondido, Palomar Mountain 447.0000 W6NWG San Diego  OPEN
# Hesperia 447.0000 KC6OPU San Bernardino  OPEN
# Loma Linda 447.0000 KE6CPF San Bernardino  OPEN
# Rancho Palos Verdes 447.0000 W6TRW Los Angeles  OPEN
# Redlands 447.0000  San Bernardino  CLOSED
# Redlands 447.0000 AI6BX San Bernardino  OPEN
# Yucca Valley, Paxton Hill 447.0000 WB6CDF San Bernardino  OPEN
# Gilman Hot Springs, Daniel Peak 447.0200 N6AJB Riverside  CLOSED
# Lake Arrowhead, Heaps Peak 447.0200 N6AJB San Bernardino  PRIVATE
# Lake Forest, Santiago Peak 447.0200 N6AJB Orange  PRIVATE
# Oak Glen, Yucaipa Ridge 447.0200 N6AJB San Bernardino  PRIVATE
# Redlands, Tremont Ranch 447.0200 N6AJB San Bernardino  CLOSED
# Ridgecrest 447.0200 W5HMV Kern  OPEN
# Thousand Oaks 447.0200 KC6IJM Los Angeles  OPEN
# Gorman, Frazier Mountain 447.0400 N6SMU Los Angeles  OPEN
# San Diego, Otay Mtn 447.0400 KK6BAD San Diego  OPEN
# Sylmar, Contractors Point 447.0400 WA6IRC Los Angeles  OPEN
# Lake Arrowhead, Heaps Peak 447.0800 K6ZXZ San Bernardino  CLOSED
# Corona, Sierra Peak 447.1000 WB6ORK Riverside  CLOSED
# Gorman, Frazier Mountain 447.1000 WB6ORK Ventura  CLOSED
# Diamond Bar 447.1400 WA6TTL Los Angeles  PRIVATE
# Palm Springs 447.1400 K6IFR Riverside  OPEN
# Ventura 447.1400 WA6TTL Ventura  PRIVATE
# Chatsworth, Chatsworth Peak 447.1600 WA6TTL Ventura  PRIVATE
# Lomita 447.1600 WA6TTL Los Angeles  PRIVATE
# Santa Barbara, Santa Ynez Peak 447.1600 W6KGB Santa Barbara  PRIVATE
# Lake Forest, Santiago Peak 447.1800 KG6GI Orange  CLOSED
# San Diego 447.1900 KJ6LKA San Diego  OPEN
# Chatsworth, Oat Mountain 447.2000 WB6EKU Los Angeles  OPEN
# Chatsworth, Oat Mountain 447.2000 K6PUW Los Angeles  OPEN
# Coronado 447.2000 W6SH San Diego  OPEN
# Rancho Cucamonga 447.2000 K6ONT San Bernardino  OPEN
# Santa Barbara, Painted Cave 447.2000 N6HYM Santa Barbara  OPEN
# Thousand Palms 447.2000 KA6GBJ Riverside  OPEN
# Wrightwood, Table Mountain 447.2000 WR6AZN Los Angeles  OPEN
# Riverside, Box Springs 447.2200 K6PIN Riverside  CLOSED
# Santa Ynez, Santa Ynez Peak 447.2200 WB6TZE Santa Barbara  CLOSED
# Sylmar, Contractors Pt 447.2200 KC6PXL Los Angeles  CLOSED
# Glendale, Mt Lukens 447.2400 WA6UZS Los Angeles  CLOSED
# La Presa, San Miguel Mountain 447.2600 AA4CD San Diego  CLOSED
# San Marcos 447.2600 WD6FZA San Diego  OPEN
# Running Springs 447.2800 WR6HP San Bernardino  CLOSED
# San Dimas, Johnstone Peak 447.3000 W6NRY Los Angeles  CLOSED
# Vista Park, San Marcos Peak 447.3000 AA4CD San Diego  OPEN
# Fontana 447.3200 KA6GRF San Bernardino  OPEN
# Fountain Valley 447.3200 WA6FV Orange  OPEN
# Palm Desert 447.3200 W6DRA Riverside  OPEN
# Palm Springs, Edom Hill 447.3200 K6JR Riverside  OPEN
# San Diego, Kearney Mesa 447.3200 W6UUS San Diego  OPEN
# San Diego, Kearney Mesa 447.3200 WB6WLV San Diego  OPEN
# Ventura, South Mtn 447.3200 WA6ZSN Ventura  OPEN
# West Los Angeles 447.3200 N6GLA Los Angeles  OPEN
# Sylmar, Contractors Pt 447.3400 W6FRT Los Angeles  OPEN
# Gorman, Frazier Mountain 447.3600 WR6FM Ventura  CLOSED
# San Diego 447.3600 AA4CD San Diego  CLOSED
# Lake Forest, Santiago Peak 447.3800 W6YJ Orange  PRIVATE
# Murrieta 447.4000 KE6UPI Riverside  OPEN
# Wrightwood, Blue Ridge 447.4400 KD6OFD Los Angeles  CLOSED
# Pine Cove 447.4800 N6MRN Riverside  OPEN
# Thousand Oaks 447.4800 W8AKF Ventura  CLOSED
# Agoura, Castro Peak 447.5000 KE6HGO Los Angeles  PRIVATE
# Carlsbad 447.5000 N0VDM San Diego  OPEN
# Chino 447.5000 K0JPK San Bernardino  CLOSED
# El Cajon 447.5200 W6HDC San Diego  OPEN
# Pomona, Sunset Ridge 447.5200 K6CF San Bernardino  CLOSED
# Pomona, Sunset Ridge 447.5200 W6GAE San Bernardino  CLOSED
# Saugus, Oat Mountain 447.5200 KF6FM Los Angeles  OPEN
# Lake Forest, Santiago Peak 447.5400 KB6CRE Orange  CLOSED
# Chatsworth, Oat Mountain 447.5600 WB6LST Los Angeles  CLOSED
# Alpine 447.5800 K6KTA San Diego  OPEN
# Arcadia, Santa Anita Ridge 447.5800 KI6DYV Los Angeles  OPEN
# Arcadia, Santa Anita Ridge 447.5800 K6JSI Los Angeles  OPEN
# Barstow 447.5800 KE6JZS San Bernardino  OPEN
# Indio, Chiriaco Smt 447.5800 W6KSN Riverside  OPEN
# Landers, Goat Mountain 447.5800 WB6CDF San Bernardino  OPEN
# Thousand Oaks 447.6000 KE6DTF Ventura  CLOSED
# Pomona, Sunset Ridge 447.6200 N6DD San Bernardino  PRIVATE
# Bakersfield, Breckenridge Mountain 447.6400 K6JSI Kern  OPEN
# La Presa, Mt Otay 447.6400 W6PL San Diego  CLOSED
# San Diego, Otay Mtn 447.6400 W6PL San Diego  OPEN
# San Diego, Otay Mtn 447.6400 K6JSI San Diego  OPEN
# Baker, Turquoise Mountain 447.6800  San Bernardino  OPEN
# Lake Forest, Santiago Peak 447.6800 K6UHF Orange  CLOSED
# Lake Forest, Santiago Peak 447.7000 W6YQY Orange  CLOSED
# Claremont, Sunset Ridge 447.7200 N6DKA Los Angeles  CLOSED
# Yucaipa, Snow Peak 447.7400 N6AJB San Bernardino  PRIVATE
# Santa Monica, Saddle Peak 447.7800 W6KGB Los Angeles  PRIVATE
# Altadena, Mt Harvard 447.8000 NO7BS Los Angeles  OPEN
# Escondido, Palomar Mountain 447.8000 K6RIF San Diego  OPEN
# Chatsworth, Oat Mountain 447.8200 KE6PGN Los Angeles  PRIVATE
# Santa Monica, Saddle Pk 447.8400 WA6JQB Los Angeles  CLOSED
# Santa Ynez 447.8400 KK6GFX Santa Barbara  OPEN
# Gorman, Frazier Mountain 447.8600 KK6AC Ventura  OPEN
# Santa Monica, Saddle Pk 447.8600 WR6SP Los Angeles  CLOSED
# Alpine 447.9000 WD6AML San Diego  OPEN
# Chatsworth, Oat Mountain 447.9000 WD6AML Los Angeles  PRIVATE
# Desert Center, Chuckwalla Mountains 447.9000 WD6AML Riverside  OPEN
# San Dimas, Johnstone Peak 447.9000 WD6AML Los Angeles  OPEN
# Vista 447.9000 KA3AJM San Diego  OPEN
# Pomona, Sunset Ridge 447.9200 N6XPG Los Angeles  PRIVATE
# Tehachapi, Double Mtn. 447.9200 KI6HHU Kern  OPEN
# Huntington Beach 447.9400 W6BRP Orange  CLOSED
# La Crescenta 447.9600 NW6B Los Angeles  CLOSED
# Running Springs 447.9800 KV6D San Bernardino  CLOSED
# Tujunga 447.9800 NW6B Los Angeles  CLOSED
# Glendale, Mt Lukens 448.0200 WR6TWE Los Angeles  CLOSED
# San Diego, Otay Mountain 448.0200 WR6MO San Diego  CLOSED
# Brawley, Black Mountain 448.0400 WD6AWP Imperial  CLOSED
# Lake Forest, Santiago Peak 448.0400 WD6AWP Orange  CLOSED
# Lake Forest, Santiago Peak 448.0600 K6JSI Orange  OPEN
# Lake Forest, Santiago Peak 448.0800 KD6ZLZ Riverside  OPEN
# Lake Forest, Santiago Peak 448.1200 KA6JRG Orange  PRIVATE
# Lake Forest, Santiago Peak 448.1400 WB6SRC Orange  CLOSED
# Yermo, Mt. Rodman 448.1400 KF6FM San Bernardino  CLOSED
# Baker, Turquoise Mountain 448.1600 W7DOD San Bernardino  CLOSED
# Yucaipa, Snow Peak 448.1600 W7DOD San Bernardino  PRIVATE
# Lake Arrowhead, Heaps Peak 448.1800 WB6TZU San Bernardino  PRIVATE
# Ventura, Red Mountain 448.1800 K6ERN Ventura  OPEN
# San Dimas, Johnstone Peak 448.2600 K6IRF Los Angeles  PRIVATE
# Yermo, Mount Rodman 448.2600 WB6TNP San Bernardino  CLOSED
# Corona, Sierra Peak 448.2800 K6ARN Orange  OPEN
# San Diego, Old Town 448.2800 KM6RPT San Diego  OPEN
# Lake Forest, Santiago Peak 448.3000 WA6ZJT Orange  CLOSED
# Lake Forest, Santiago Peak 448.3200 W6KRW Orange  CLOSED
# Lake Forest, Santiago Peak 448.3200 WA6ZJT Orange  CLOSED
# Bellflower 448.3400 KB6MRC Los Angeles  OPEN
# Chula Vista, Sweetwater Authority Water Tank 448.3400 K6QM San Diego  OPEN
# Oxnard 448.3400 W6KGB Ventura  OPEN
# San Dimas, Johnstone Peak 448.3400 K6OES Los Angeles  OPEN
# Santa Clarita 448.3400 N6NMC Los Angeles  OPEN
# Wrightwood, Blue Ridge 448.3800 WD6AWP Los Angeles  PRIVATE
# Bell 448.4000 N6WZK Los Angeles  PRIVATE
# Barstow, Ord Mountain 448.4200 W6ATN San Bernardino  CLOSED
# Crestline, Strawberry Peak 448.4200 K6IOJ San Bernardino  CLOSED
# La Canada, Mt. Wilson 448.4200 W6ATN Los Angeles  CLOSED
# Pomona, Sunset Ridge 448.4600 K6PIN Los Angeles  CLOSED
# San Diego, San Miguel Mtn. 448.4600 KK6KD San Diego  OPEN
# Victorville, Quartzite Mountain 448.4600 N6RMH Los Angeles  CLOSED
# Poway, Mt Woodson 448.5200 KI6KQU San Diego  CLOSED
# Escondido, Palomar Mountain 448.5400 K6JXY San Diego  OPEN
# Glendale, Mt Thom 448.5400 N6MQS Los Angeles  PRIVATE
# Westwood, UCLA 448.5400 W6YRA Los Angeles  CLOSED
# Glendale, Mount Lukens 448.5600 WA6ZRB Los Angeles  PRIVATE
# Newbury Park, Rasnow Peak 448.6000 W6RRN Ventura  PRIVATE
# Oxnard 448.8000 K6BBK Ventura  OPEN
# Ridgecrest, El Paso Peak 448.8000 WI6RE Kern  OPEN
# Vista 448.8000 K6JSI San Diego  CLOSED
# Altadena, Mt Wilson 448.9000 WA6ZSG Los Angeles  CLOSED
# Santa Barbara, Santa Ynez Peak 448.9000 K6JSI Santa Barbara  OPEN
# Victorville, Quartzite Mountain 448.9000 K6PNG San Bernardino  CLOSED
# Lake Forest, Santiago Peak 448.9200 N6SLD Orange  CLOSED
# El Cajon, Rattlesnake Peak 448.9400 N6SIX San Diego  OPEN
# San Diego 448.9400 KE6VK San Diego  CLOSED
# Thousand Oaks 448.9400 K6JSI Ventura  OPEN
# Escondido, Palomar Mountain 448.9600 KE6VK San Diego  CLOSED
# San Diego 449.0000 KJ6GRS San Diego  OPEN
# Santa Ynez, Santa Ynez Peak 449.0000 WA6TZE Santa Barbara  CLOSED
# Lake Forest, Santiago Peak 449.0375 KA6P Orange  OPEN
# Wrightwood 449.0375 KA6P San Bernardino  OPEN
# San Diego, Otay Mountain 449.0600 K6RRR San Diego  OPEN
# Barstow 449.0800 N6TAP San Bernardino  OPEN
# Escondido, Palomar Mountain 449.0800 K6JSI San Diego  CLOSED
# Redlands 449.0800 AD5MT San Bernardino  OPEN
# Thousand Oaks, Rasnow Peak 449.0800 WA6TTL Ventura  PRIVATE
# Commerce 449.1000 N6WZK Los Angeles  PRIVATE
# Whittier 449.1000 N6UQX Los Angeles  OPEN
# San Diego, Otay Mountain 449.1200 K6XI San Diego  OPEN
# San Dimas, Johnstone Peak 449.1200 N6KHZ Los Angeles  CLOSED
# Lompoc, Tranquillon Peak 449.1400 W6AB Santa Barbara  OPEN
# Alpine, Monument Peak 449.1800 N6LVR San Diego  OPEN
# Mt. Wilson 449.2000 N6CIZ Los Angeles  OPEN
# San Diego, Otay Mountain 449.2000 WB6WLV San Diego  OPEN
# Victorville, Quartzite Mountain 449.2000 KK6SVL San Bernardino  OPEN
# Glendale, Mt Lukens 449.2200 WB6YMH Los Angeles  CLOSED
# Rancho Palos Verdes 449.2200 WB6YMH Los Angeles  OPEN
# San Diego, Otay Mountain 449.2200 WB6CYT San Diego  CLOSED
# Cathedral City, Edom Hill 449.2400 K6JR Riverside  CLOSED
# Escondido 449.2400 N6WB San Diego  OPEN
# Pine Cove 449.2800 WB6VSJ Riverside  OPEN
# Escondido, Palomar Mountain 449.3000 W6ZN San Diego  OPEN
# Moreno Valley, Box Springs Mtn. 449.3000 KI6REC Riverside  OPEN
# Santa Ynez, Broadcast Peak 449.3000 WB6OBB Santa Barbara  OPEN
# Seal Beach 449.3000 KC6YNQ Orange  OPEN
# Escondido, Palomar Mountain 449.3200 W6YJ San Diego  PRIVATE
# Onyx, Onyx Peak 449.3400 KB6CRE San Bernardino  CLOSED
# San Antonio Heights, Sunset Ridge  449.3600 N6WZK San Bernardino  OPEN
# Glendale, Mt Lukens 449.3800 KI6KQU Los Angeles  CLOSED
# San Diego, Otay Mountain 449.3800 KW6HRO San Diego  OPEN
# Pomona, Sunset Ridge 449.4200 KE6TZF Los Angeles  PRIVATE
# San Diego, Mount Otay 449.4400 K6XI San Diego  OPEN
# Thousand Oaks 449.4400 W6AMG Ventura  OPEN
# Chatsworth, Oat Mountian 449.4600 N6LRB Los Angeles  OPEN
# Harbor City 449.4600 N9QE Los Angeles  OPEN
# San Diego 449.4625 AI6DZ San Diego  OPEN
# Santa Monica 449.4625 KJ6UVT Los Angeles  CLOSED
# Altadena, Mt Wilson 449.4800 N6YN Los Angeles  CLOSED
# Juniper Hills 449.5000 WA6GDF Los Angeles  OPEN
# Pomona, Sunset Ridge 449.5000 K9KAO Los Angeles  OPEN
# San Diego, Mount Laguna 449.5000 WB6WLV San Diego  OPEN
# Bell 449.5600 N6WZK Los Angeles  PRIVATE
# Santa Barbara, Santa Ynez Peak 449.5600 WB6BBE Santa Barbara  PRIVATE
# Whittier 449.5600 N6WZK Los Angeles  PRIVATE
# San Diego, Mount Laguna 449.5800 K6KTA San Diego  OPEN
# San Diego, Otay Mountain 449.6000 WV6H San Diego  PRIVATE
# San Diego 449.6000 WA6YVX San Diego  OPEN
# Hollywood, Hollywood Hills 449.6200 KB6IBB Los Angeles  CLOSED
# Lake Arrowhead, Heaps Peak 449.6600 W6YJ San Bernardino  PRIVATE
# Covina, Covina PD 449.6800 N7YMM Los Angeles  OPEN
# Lake Arrowhead, Heaps Peak 449.6800 WA6RQD San Bernardino  CLOSED
# Altadena, Mt. Wilson 449.7000 N6CIZ Los Angeles  OPEN
# Calexico 449.7000 K6CLX Imperial  OPEN
# Cloverdale 449.7000 WB6QAZ Sonoma  OPEN
# Palm Springs, Tram 449.7000 W6DRA Riverside  OPEN
# San Diego, Otay Mtn 449.7000 WA6OSB San Diego  OPEN
# Victorville, Quartzite Mountain 449.7000 W6NVY San Bernardino  OPEN
# Altadena, Mt Wilson 449.7200 WA6TTL Los Angeles  PRIVATE
# Escondido, Palomar Mountain 449.7200 WA6TTL San Diego  PRIVATE
# Lake Forest, Santiago Peak 449.7400 WA6TTL Orange  PRIVATE
# Malibu, Santa Monica Mountains 449.7400 W6KGB Los Angeles  PRIVATE
# San Diego, Otay Mountain 449.7400 W6KGB San Diego  PRIVATE
# Wrightwood, Blue Ridge 449.7400 W6KGB Los Angeles  PRIVATE
# Lake Forest, Santiago Peak 449.7600 WA6DPB Orange  CLOSED
# Barstow, Ord Mountain 449.7800 WR6OM San Bernardino  CLOSED
# Poway, Mt Woodson 449.7800 N6SIX San Diego  OPEN
# San Diego, Otay Mountain 449.7800 WB6DTR San Diego  CLOSED
# Signal Hill, Signal Hill Tower 449.7800 K6CHE Los Angeles  OPEN
# Glendale, Mt Lukens 449.8000 WA6DPB Los Angeles  CLOSED
# Lake Forest, Santiago Peak 449.8000 WB6BWU Orange  CLOSED
# Rancho Palos Verdes 449.8200 KE6LE Los Angeles  PRIVATE
# Rancho Palos Verdes 449.8200 KE6LE Los Angeles  OPEN
# Anaheim, HRO 449.8400 W6HRO Orange  OPEN
# San Diego 449.8400 N6OEI San Diego  OPEN
# Pomona, Sunset Ridge 449.8800 K6TEM Los Angeles  OPEN
# El Cajon 449.9000 KF6YB San Diego  OPEN
# Fairbanks Ranch 449.9000 K6RYA San Diego  OPEN
# La Mesa 449.9000 KF6YB San Diego  OPEN
# Valley Center, Paradise Mountain 449.9200 N6VCC San Diego  OPEN
# Rancho Palos Verdes, San Pedro Hill 449.9800 K6IUM Los Angeles  CLOSED
# Running Springs 449.9800 KA6MEP San Bernardino  PRIVATE
# San Diego, Otay Mountain 449.9800 K6RIF San Diego  OPEN
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-b962b674b96c> in <module>
#       2 table_rows = soup.find_all('tr')[4:]
#       3 for item in table_rows:
# ----> 4     freq = item.find('a').text
#       5     call_sign = item.find_all('td', attrs={'class': None})[3].text
#       6     county = item.find_all('td', attrs={'class': None})[2].text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# pushes mongo db table to pandas dataframe
stations = db.stations
df = pd.DataFrame(list(stations.find()))
df = df[['call sign', 'location', 'frequency', 'county', 'usage']]
df.head(10)
# Out:
#   call sign       location frequency       county  usage
# 0     KC7NP  Moreno Valley  425.4250    Riverside   OPEN
# 1     W6IOS       San Jose  430.3000  Santa Clara   OPEN
# 2    KI6PNB          Chico  440.0000        Butte   OPEN
# 3    WA6FSP        Fremont  440.0000      Alameda   OPEN
# 4     N6VRC         Fresno  440.0025       Fresno   OPEN
# 5      W6PE         Sonoma  440.0125       Sonoma   OPEN
# 6    KI6KGN        Fremont  440.0250      Alameda   OPEN
# 7     N6TZE       Pacifica  440.0250    San Mateo   OPEN
# 8    WA6RQZ          Ukiah  440.0250    Mendocino   OPEN
# 9      WV6F      Vacaville  440.0250       Solano   OPEN
